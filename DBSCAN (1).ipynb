# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

# %%
points=np.array([[3,7],[4,6],[5,5],[6,4],[7,3],[6,2],[7,2],[8,4],[3,3],[2,6],[3,5],[2,4]])

# %%
dbscan = DBSCAN(eps=1.9,min_samples=4)
labels=dbscan.fit_predict(points)

# %%
from enum  import unique
unique_labels = np.unique(labels)
for label in unique_labels:
   cluster_points = points[labels == label]
   if cluster_points.size == 0:
      continue
   if label == -1:
      plt.scatter(cluster_points[:,0], cluster_points[:,1], c = 'k',marker='x',label='Noise')
   else:
      plt.scatter(cluster_points[:,0], cluster_points[:,1], label=f'cluster {label}')
plt.legend()
plt.title('DBSCAN Clustering Result')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True)
plt.show()

# %%
print("Cluster labels for each pomt:")
for i, label in enumerate(labels, start=1):
    print(f"P{i}: Cluster {label if label != -1else'Noise'}")
# Out:
# Cluster labels for each pomt:
# P1: Cluster 0
# P2: Cluster 0
# P3: Cluster 0
# P4: Cluster 1
# P5: Cluster 1
# P6: Cluster 1
# P7: Cluster 1
# P8: Cluster 1
# P9: Cluster Noise
# P10: Cluster 0
# P11: Cluster 0
# P12: Cluster 0
# <>:3: SyntaxWarning: invalid decimal literal
# <>:3: SyntaxWarning: invalid decimal literal
# /tmp/ipython-input-34-3417092259.py:3: SyntaxWarning: invalid decimal literal
#   print(f"P{i}: Cluster {label if label != -1else'Noise'}")

# %%
n_clusters=len(set(labels)) - (1 if -1 in labels else 0)
print("\nNumber of clusters forme (excluding noise):",n_clusters)
# Out:
# Number of clusters forme (excluding noise): 2
